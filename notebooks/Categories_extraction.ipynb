# %%
import pandas as pd

# %%
import gensim
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
stemmer = PorterStemmer()

# %%
def lemmatize_stemming(text):
    text = stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='n'))
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and token not in stopwords.words('english') and len(token) > 3:
            result.append(lemmatize_stemming(token))
            
    return result

# %%
data=pd.read_csv('../processed_data/final2.csv' )

# %%
data['token']=''

# %%
data['token']=data['text'].apply(preprocess)

# %%
data
# Out:
#        title                                               text  \
# 0          0  The next morning the young prince set forth in...
# 1          1  "  Once upon a time there lived in a city of H...
# 2          2  "  Once upon a time there was a very rich and ...
# 3          3  "  Once there lived a certain king who underst...
# 4          4  "  In the midst of a sandy desert somewhere in...
# ...      ...                                                ...
# 6655    Zeri  Welcome to Universe, the definitive source for...
# 6656   Ziggs  Ziggs was born with a talent for tinkering, bu...
# 6657  Zilean  Icathia, most desolate and cursed of lands, wa...
# 6658     Zoe  As befits her Targonian Aspect’s nature, Zoe d...
# 6659    Zyra  Zyra’s memory is long, and runs as deep as the...
#
#      classification                                              token
# 0               NaN  [morn, young, princ, forth, quest, fish, take,...
# 1               NaN  [time, live, citi, hindustan, seller, scent, e...
# 2               NaN  [time, rich, power, king, spite, marri, time, ...
# 3               NaN  [live, certain, king, understand, languag, bir...
# 4               NaN  [midst, sandi, desert, asia, eye, travel, refr...
# ...             ...                                                ...
# 6655            NaN  [welcom, univ, definit, sourc, world, leagu, l...
# 6656            NaN  [zigg, bear, talent, tinker, chaotic, hyperact...
# 6657            NaN  [icathia, desol, cur, land, rich, diver, civil...
# 6658            NaN  [befit, targonian, aspect, natur, come, attent...
# 6659            NaN  [zyra, memori, long, run, deep, root, earth, k...
#
# [6660 rows x 4 columns]

# %%
data['token'][6659]
# Out:
# ['zyra',
#  'memori',
#  'long',
#  'run',
#  'deep',
#  'root',
#  'earth',
#  'kind',
#  'young',
#  'rune',
#  'war',
#  'rage',
#  'mortal',
#  'armi',
#  'fight',
#  'key',
#  'creation',
#  'hide',
#  'jungl',
#  'south',
#  'kumungu',
#  'great',
#  'river',
#  'divid',
#  'eastern',
#  'shurima',
#  'fabl',
#  'garden',
#  'element',
#  'magic',
#  'turn',
#  'soil',
#  'strang',
#  'unpredict',
#  'way',
#  'give',
#  'rise',
#  'fierc',
#  'carnivor',
#  'plant',
#  'prey',
#  'creatur',
#  'stray',
#  'reach',
#  'infest',
#  'devour',
#  'care',
#  'squabbl',
#  'mortal',
#  'content',
#  'mere',
#  'coil',
#  'vine',
#  'forest',
#  'swampland',
#  'zyra',
#  'nourish',
#  'plenti',
#  'midst',
#  'small',
#  'compani',
#  'soldier',
#  'allegi',
#  'long',
#  'lose',
#  'time',
#  'advanc',
#  'land',
#  'search',
#  'forget',
#  'prize',
#  'ambiti',
#  'sorceress',
#  'home',
#  'bind',
#  'succumb',
#  'noxiou',
#  'fume',
#  'spore',
#  'accur',
#  'place',
#  'denizen',
#  'garden',
#  'spine',
#  'tendril',
#  'lash',
#  'armor',
#  'flesh',
#  'sadist',
#  'ea',
#  'fight',
#  'valiantli',
#  'warrior',
#  'know',
#  'hold',
#  'long',
#  'turn',
#  'sorceress',
#  'save',
#  'gather',
#  'power',
#  'work',
#  'mighti',
#  'blast',
#  'burn',
#  'runic',
#  'symbol',
#  'cast',
#  'eeri',
#  'light',
#  'thorni',
#  'overgrowth',
#  'close',
#  'instant',
#  'rogu',
#  'spark',
#  'ignit',
#  'ga',
#  'swamp',
#  'result',
#  'magic',
#  'explo',
#  'oblit',
#  'live',
#  'thing',
#  'mile',
#  'scatter',
#  'survivor',
#  'rune',
#  'war',
#  'know',
#  'fate',
#  'befal',
#  'garden',
#  'centuri',
#  'pass',
#  'land',
#  'battl',
#  'fight',
#  'lifeless',
#  'grind',
#  'depth',
#  'stir',
#  'long',
#  'energi',
#  'unleash',
#  'settl',
#  'curdl',
#  'nourish',
#  'fallout',
#  'seedpod',
#  'bulg',
#  'pul',
#  'unnatur',
#  'life',
#  'creatur',
#  'claw',
#  'free',
#  'gasp',
#  'confu',
#  'behold',
#  'break',
#  'chang',
#  'world',
#  'brim',
#  'vital',
#  'idea',
#  'mind',
#  'puzzl',
#  'conflict',
#  'memori',
#  'draw',
#  'loami',
#  'earth',
#  'forc',
#  'fledgl',
#  'consciou',
#  'recal',
#  'warmth',
#  'tast',
#  'rain',
#  'word',
#  'power',
#  'agoni',
#  'mortal',
#  'death',
#  'call',
#  'zyra',
#  'understand',
#  'ventur',
#  'wildland',
#  'birthplac',
#  'zyra',
#  'know',
#  'differ',
#  'creatur',
#  'encount',
#  'mortal',
#  'fear',
#  'unplea',
#  'thing',
#  'ether',
#  'entiti',
#  'tend',
#  'caprici',
#  'arrog',
#  'respect',
#  'realm',
#  'inhabit',
#  'despoil',
#  'mere',
#  'presenc',
#  'fill',
#  'zyra',
#  'rage',
#  'contempt',
#  'unbidden',
#  'life',
#  'spring',
#  'footstep',
#  'voraci',
#  'plant',
#  'form',
#  'chang',
#  'evolv',
#  'beneath',
#  'gaze',
#  'hurl',
#  'poison',
#  'barb',
#  'sprout',
#  'fresh',
#  'tendril',
#  'alarm',
#  'rate',
#  'unroot',
#  'free',
#  'wander',
#  'zyra',
#  'deadli',
#  'progeni',
#  'fee',
#  'grow',
#  'strangl',
#  'life',
#  'world',
#  'blight',
#  'farmland',
#  'overrun',
#  'entir',
#  'settlement',
#  'crush',
#  'warrior',
#  'brave',
#  'foolish',
#  'confront',
#  'leav',
#  'menageri',
#  'botan',
#  'horror',
#  'wake',
#  'river',
#  'shurima',
#  'begin',
#  'anew',
#  'strang',
#  'flora',
#  'sight',
#  'bank',
#  'spread',
#  'slowli',
#  'westward',
#  'pass',
#  'season',
#  'pull',
#  'earth',
#  'purg',
#  'growth',
#  'slow']

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 dictionary = gensim.corpora.Dictionary(processed_docs)
#
# NameError: name 'processed_docs' is not defined
