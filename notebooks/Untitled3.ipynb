# %%
import pandas as pd
import numpy as np

# %%
super_stories_df = pd.read_csv('../processed_data/SuperStories.csv')
archive_2 = pd.read_csv('../processed_data/achives_2.csv')
archive_1 = pd.read_csv('../processed_data/archive1.csv')
archive_13 = pd.read_csv('../processed_data/archive_13.csv')
archive_30 = pd.read_csv('../processed_data/archive_30.csv')
beatrix_potter_stories = pd.read_csv('../processed_data/beatrix_potter_stories.csv')
grimms = pd.read_csv('../processed_data/grimms_fairytales.csv')
rudyard = pd.read_csv('../processed_data/rudyard_kipling_stories.csv')
raph = pd.read_csv('../processed_data/texts_raph.csv')

# %%
beatrix_potter_stories['IsHorror?'].drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 beatrix_potter_stories['IsHorror?'].drop()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4674 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4675 def drop(
#    4676     self,
#    (...)
# ...

# %%
final = pd.concat([super_stories_df,archive_2, archive_1, archive_13, archive_30, beatrix_potter_stories, grimms, rudyard, raph], axis=0, ignore_index=True)

# %%
final
# Out:
#        title                                               text  Unnamed: 0  \
# 0          0  The next morning the young prince set forth in...         NaN
# 1          1  "  Once upon a time there lived in a city of H...         NaN
# 2          2  "  Once upon a time there was a very rich and ...         NaN
# 3          3  "  Once there lived a certain king who underst...         NaN
# 4          4  "  In the midst of a sandy desert somewhere in...         NaN
# ...      ...                                                ...         ...
# 6657    Zeri                                                NaN       154.0
# 6658   Ziggs                                                NaN       155.0
# 6659  Zilean                                                NaN       156.0
# 6660     Zoe                                                NaN       157.0
# 6661    Zyra                                                NaN       158.0
#
# ...
